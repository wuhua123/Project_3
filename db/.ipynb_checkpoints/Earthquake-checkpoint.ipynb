# %%
import requests
import json
import pandas as pd

# %%
quakes_response=requests.get("https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson")
#,
                   # params={
        #'starttime':"2000-01-01",
        #"maxlatitude":"58.723",
        #"minlatitude":"50.008",
        #"maxlongitude":"1.67",
        #"minlongitude":"-9.756",
        #"minmagnitude":"1",
        #"endtime":"2015-07-13",
        #"orderby":"time-asc"}
                  #

# %%
quakes_response
# Out:
# <Response [200]>

# %%
requests_json = json.loads(quakes_response.text)

# %%
type(requests_json)
# Out:
# dict

# %%
requests_json.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
type(requests_json['features'])
# Out:
# list

# %%
len(requests_json['features'])
# Out:
# 1497

# %%
type(requests_json['features'][0])
# Out:
# dict

# %%
requests_json['features'][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
data=json.loads(quakes_response.text)

# %%
for quake in data['features']:
    print("This quake has magnitude", quake['properties']['mag'])
    print(" ... and is at longitude",quake['geometry']['coordinates'][0])
    print(" ... and latitude", quake['geometry']['coordinates'][1])
    print()
# Out:
# This quake has magnitude 0.78
#  ... and is at longitude -122.7798309
#  ... and latitude 38.8043327
#
# This quake has magnitude 1.06
#  ... and is at longitude -122.8133316
#  ... and latitude 38.8288345
#
# This quake has magnitude 2.38
#  ... and is at longitude -155.2633362
#  ... and latitude 19.4278336
#
# This quake has magnitude 3.3
#  ... and is at longitude -153.0362
#  ... and latitude 60.0646
#
# This quake has magnitude 0.28
#  ... and is at longitude -116.7781667
#  ... and latitude 33.4933333
#
# This quake has magnitude 4.4
#  ... and is at longitude 141.902
#  ... and latitude 37.0405
#
# This quake has magnitude 1.9
#  ... and is at longitude -151.0094
#  ... and latitude 61.0119
#
# This quake has magnitude 1.01
#  ... and is at longitude -122.7343369
#  ... and latitude 38.7841682
#
# This quake has magnitude 0.32
#  ... and is at longitude -116.6915
#  ... and latitude 33.5306667
#
# This quake has magnitude 2.34
#  ... and is at longitude -116.7966667
# ...

# %%
data['features'][0]['properties'].keys()
# Out:
# dict_keys(['mag', 'place', 'time', 'updated', 'tz', 'url', 'detail', 'felt', 'cdi', 'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'code', 'ids', 'sources', 'types', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type', 'title'])

# %%
data['features'][0]['properties']['mag']
# Out:
# 0.78

# %%
data_df = pd.DataFrame({'mag':[],
                        'place':[],
                        'time':[],
                        'updated':[],
                        'tz':[],
                        'url':[], 
                        'detail':[], 
                        'felt':[], 
                        'magType':[], 
                        'tittle':[], 
                        
                       })

print(data_df)
# Out:
# Empty DataFrame
# Columns: [mag, place, time, updated, tz, url, detail, felt, magType, tittle]
# Index: []

# %%
quakes = requests_json['features']
largest_so_far = quakes[0]

for quake in quakes:
    if quake['properties']['mag'] > largest_so_far['properties']['mag']:
        largest_so_far = quake
        
largest_so_far
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 7.5,
#   'place': '115km ESE of Palora, Ecuador',
#   'time': 1550830642410,
#   'updated': 1550899792389,
#   'tz': -300,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000jlfv',
#   'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us2000jlfv.geojson',
#   'felt': 404,
#   'cdi': 6.7,
#   'mmi': 6.99,
#   'alert': 'yellow',
#   'status': 'reviewed',
#   'tsunami': 1,
#   'sig': 1136,
#   'net': 'us',
#   'code': '2000jlfv',
#   'ids': ',at00pnbol0,pt19053000,us2000jlfv,',
#   'sources': ',at,pt,us,',
#   'types': ',dyfi,finite-fault,general-text,geoserve,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#   'nst': None,
#   'dmin': 2.073,
#   'rms': 1.3,
#   'gap': 37,
#   'magType': 'mww',
#   'type': 'earthquake',
#   'title': 'M 7.5 - 115km ESE of Palora, Ecuador'},
#  'geometry': {'type': 'Point', 'coordinates': [-77.0231, -2.199, 132.36]},
#  'id': 'us2000jlfv'}

# %%
quakes
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 0.78,
#    'place': '4km NW of The Geysers, CA',
#    'time': 1550907663810,
#    'updated': 1550907791711,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73144786',
#    'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73144786.geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '73144786',
#    'ids': ',nc73144786,',
#    'sources': ',nc,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.01281,
#    'rms': 0.03,
#    'gap': 63,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 4km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.7798309, 38.8043327, 0.85]},
#   'id': 'nc73144786'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.06,
# ...

# %%
quakes= data['features'][0]['properties']['mag']

# %%
for quake in quakes
    data_df["mag"].append(quake['properties']['mag'])
    #data_df["place"].append(quake['properties']['place'])
    #data_df["time"].append(quake['properties']['time'])
    #data_df["updated"].append(quake['properties']['updated'])
    #data_df["type"].append(quake['properties']['type'])
# Out:
#   File "<ipython-input-1-2370326516cb>", line 1
#     for quake in quakes
#                        ^
# SyntaxError: invalid syntax

# %%
#def create_dataframe(d):
    #features = d['features']
    #properties = [x['properties'] for x in features]
    #geometries = [x['geometry'] for x in features]
    #coordinates = [x['coordinates'] for x in geometries]
    #times = [convert_timestamp(x['time']) for x in properties]
    #dd = {
        #'Place': [x['place'] for x in properties],
        #'Magnitude': [x['mag'] for x in properties],
        #'Time': times,
        #'Detail': [x['detail'] for x in properties],
        #'Longitude': [x[0] for x in coordinates],
        #'Latitude': [x[1] for x in coordinates],
        #'Depth': [x[2] for x in coordinates],
    #}
#print(dataframe.head())

# %%
#usgs = 'http://earthquake.usgs.gov/earthquakes/'
#geoJsonFeed = 'feed/v1.0/summary/4.5_month.geojson'
#url = '{}{}'.format(usgs, geoJsonFeed)
#req = requests.get(url)
#data = json.loads(req.text)
